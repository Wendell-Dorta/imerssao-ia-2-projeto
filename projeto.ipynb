# %% [markdown]
# <a href="https://colab.research.google.com/github/Wendell-Dorta/imerssao-ia-2-projeto/blob/main/projeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
# Import the Python SDK
import google.generativeai as genai


GOOGLE_API_KEY='AIzaSyBtW2zMDo5iZiAdLLAY5K8MykOwNIet2tI'
genai.configure(api_key=GOOGLE_API_KEY)

# %%
gen_config = {
    'candidate_count': 1,
    'temperature': 1
}

# %%
model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                              generation_config=gen_config)

# %%
chat = model.start_chat(history=[])

# %%
def gerar_plano_estudos(materia, objetivo, tempo):
  prompt = f"""
  Crie um plano de estudos detalhado para a matéria {materia}.
  Meu objetivo é {objetivo} e tenho {tempo} disponível para estudar.
  Inclua tópicos, subtópicos e sugestões de recursos como vídeos, artigos e exercícios.
  """
  resposta = model.generate_content(
      contents=[{"text": prompt}],
      generation_config=gen_config,
  )
  return resposta.text

def obter_insights(topico):
  prompt = f"""
  Forneça insights, exemplos, analogias e dicas para entender melhor o tópico {topico}.
  """
  resposta = model.generate_content(
      contents=[{"text": prompt}],
      generation_config=generation_config,
  )
  return resposta.text

# UI/UX com Widgets
materia_input = widgets.Text(placeholder='Digite a matéria')
objetivo_input = widgets.Text(placeholder='Seu objetivo de aprendizado')
tempo_input = widgets.Text(placeholder='Tempo disponível para estudar')
topico_input = widgets.Text(placeholder='Digite o tópico')
output = widgets.Output()
botao_plano = widgets.Button(description='Gerar Plano de Estudos')
botao_insights = widgets.Button(description='Obter Insights')

def on_botao_plano_clicked(b):
  with output:
    clear_output()
    materia = materia_input.value
    objetivo = objetivo_input.value
    tempo = tempo_input.value
    plano = gerar_plano_estudos(materia, objetivo, tempo)
    output.append_stdout(plano)

def on_botao_insights_clicked(b):
  with output:
    clear_output()
    topico = topico_input.value
    insights = obter_insights(topico)
    output.append_stdout(insights)

botao_plano.on_click(on_botao_plano_clicked)
botao_insights.on_click(on_botao_insights_clicked)

# Layout
titulo = widgets.HTML("<h1>🧠📚 Assistente de Estudos com IA</h1>")

# Criando abas para organizar o layout
abas = widgets.Tab()
abas.children = [
  widgets.VBox([materia_input, objetivo_input, tempo_input, botao_plano]),
  widgets.VBox([topico_input, botao_insights])
]
abas.set_title(0, "Gerar Plano de Estudos")
abas.set_title(1, "Obter Insights")

# Exibindo os widgets
display(titulo)
display(abas)
display(output)
# Out:
# HTML(value='<h1>🧠📚 Assistente de Estudos com IA</h1>')
# ...
# Output()
